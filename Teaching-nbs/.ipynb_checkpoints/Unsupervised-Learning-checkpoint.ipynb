# %% [markdown]
# ## Unsupervised Learning
#
# **Goal:** Start with some of the setup and examples for the ODSL Lecture!!

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **First plot:** Two Gaussian blobs

# %%
# Number of training events we'll sample / blob
N_tr = 100

# %%
# The centers of the Gaussian blobs
c1 = np.array([0,0])
c2 = np.array([2,1])

s1 = .333
s2 = .45

# %%
X1 = c1 + s1*np.random.randn(N_tr,2)
X2 = c2 + s2*np.random.randn(N_tr,2)

# %%
color1 = 'dodgerblue'
color2 = 'darkorange'
fs=20

# %%
# import os
# os.mkdir("figures/Unsup/Kmeans")

# %%
plt.scatter(*X1.T,color=color1)
plt.scatter(*X2.T,color=color1)

plt.xlabel('$x_0$',fontsize=fs)
plt.ylabel('$x_1$',fontsize=fs)

plt.savefig('figures/Unsup/Gauss_nocolor.pdf',bbox_inches='tight')

# %%
plt.scatter(*X1.T,color=color1)
plt.scatter(*X2.T,color=color2)

plt.xlabel('$x_0$',fontsize=fs)
plt.ylabel('$x_1$',fontsize=fs)

plt.savefig('figures/Unsup/Gauss_colored.pdf',bbox_inches='tight')

# %% [markdown]
# OK -- run $K$-means!

# %%
size=250
marker='X'
size=250
lw=2
alpha=.5

# %%
X = np.vstack([X1,X2])
X.shape
# Out:
# (200, 2)

# %%
plt.scatter(*X.T,color='grey',alpha=alpha)

plt.xlabel('$x_0$',fontsize=fs)
plt.ylabel('$x_1$',fontsize=fs)

plt.savefig('figures/Unsup/Kmeans/start.pdf',bbox_inches='tight')

# %%
K=2

idx1, idx2 = np.random.choice(X.shape[0], size=K,replace=False)

# %%
idx1, idx2 = (91,47)

# %%
m1 = X[idx1]
m2 = X[idx2]

mus = np.vstack([m1,m2])

# %%
colors = [color1,color2]

# %%
plt.scatter(*X.T,color='grey',alpha=alpha)

plt.scatter(*mus.T,size,marker=marker,
            linewidths=lw,edgecolors='k',
            color=colors)

plt.xlabel('$x_0$',fontsize=fs)
plt.ylabel('$x_1$',fontsize=fs)

plt.savefig('figures/Unsup/Kmeans/start_init.pdf',bbox_inches='tight')

# %% [markdown]
# Keep track of the clusters that each point gets assigned to.

# %%
dim=2

# %%
def updateClusters(X,mus):
    '''
    Update the cluster assignment
    
    Inputs:
    - X: input data
    - mus: the cluster centers
    Outputs:
    - idx: int from [0, ... K-1] of len(X.shape[0])
           for which cluster each input is assigned to
    
    '''
    
    # Infer the # of clusters and dim of the input
    K, dim = mus.shape
    assert X.shape[-1] == dim # sanity chck
    
    Z = X.reshape(-1,1,dim)-mus.reshape(1,K,dim)
    J = np.sum(Z**2,axis=-1)
    idx = np.argmin(J,axis=1)
    
    return idx


def updateCenters(X, idx):
    '''
    Update the cluster centers
    
    Inputs:
    - X: 
    - idx:
    
    Output:
    - mus: 
    
    '''
    
    K = np.max(idx)+1
    
    mus = np.vstack([np.mean(X[idx==i],axis=0) for i in range(K)])
    
    return mus

# %% [markdown]
# **Cost function**
#
# $$\mathcal{L}(c,\mu) = \sum_{i=1}^n ||x^{(i)} - \mu_{c^{(i)}}||^2$$

# %%
def costFct(X,mus,idx):
    
    J = 0
    for i,mu in enumerate(mus):
        J += np.sum((X[idx==i] - mu)**2)
    
    return J

# %%
def drawPlot(X, mus,idx, colors,  figName = ''):

    K = mus.shape[0]
    assert len(colors) == K
    
    for i, color in enumerate(colors):
        plt.scatter(*X[idx==i].T,color=color,alpha=alpha)
    
    plt.scatter(*mus.T,size,
                marker=marker,linewidths=lw,color=colors,
                edgecolors='k')

    plt.xlabel('$x_0$',fontsize=fs)
    plt.ylabel('$x_1$',fontsize=fs)

    if figName:
        plt.savefig(figName,bbox_inches='tight')

    plt.show()

# %%
figDir = "figures/Unsup/Kmeans"

# %%
Ls = []

# %%
for i in range(0,6):
    
    # Update clusters    
    idx = updateClusters(X,mus)
    drawPlot(X,mus,idx,colors,figName=f'{figDir}/start_{i}a.pdf')
    
    L = costFct(X,mus,idx)
    Ls.append(L)
    print(f'L = {L}')
    
    # Update means
    mus =  updateCenters(X, idx)
    drawPlot(X,mus,idx,colors,figName=f'{figDir}/start_{i}b.pdf')
   
    L = costFct(X,mus,idx)
    Ls.append(L)
    print(f'L = {L}')
# Out:
# L = 425.5953702355848
# L = 109.39820055067554
# L = 64.04361062214122
# L = 56.888822257158346
# L = 56.87746117870938
# L = 56.852709167535565
# L = 56.852709167535565
# L = 56.852709167535565
# L = 56.852709167535565
# L = 56.852709167535565
# L = 56.852709167535565
# L = 56.852709167535565

# %%
fs
# Out:
# 20

# %%
plt.scatter(np.arange(len(Ls))/2,Ls,64,
            color=['b','g']*(len(Ls)//2))

for l,c in zip(['E','M'],['b','g']):
    plt.scatter([],[],64,label=f'{l}-step',color=c)

plt.xlabel('Iteration',fontsize=fs)
plt.ylabel('$\mathcal{L}$',fontsize=40,rotation=0,labelpad=20,va='top',y=.9)
plt.legend(fontsize=fs,frameon=False)

ax = plt.gca()
for loc in ['right','top']:
    ax.spines[loc].set_visible(False)

ax.spines['bottom'].set_linewidth(2)
ax.spines['left'].set_linewidth(2)

xlim = plt.xlim()
_,ymax = plt.ylim()

ax.plot((xlim[1]), (0), ls="", marker=">", 
    ms=16, color="k", clip_on=False)

ax.plot((xlim[0]), (ymax), ls="", marker="^", 
    ms=16, color="k", clip_on=False)

plt.xlim(xlim)
plt.ylim(0,ymax)
plt.savefig(f'{figDir}/k2_loss.pdf',bbox_inches='tight')

# %%
Ls
# Out:
# [425.5953702355848,
#  109.39820055067554,
#  64.04361062214122,
#  56.888822257158346,
#  56.87746117870938,
#  56.852709167535565,
#  56.852709167535565,
#  56.852709167535565,
#  56.852709167535565,
#  56.852709167535565,
#  56.852709167535565,
#  56.852709167535565]

# %% [markdown]
# **TO DO:** Rinse and repeat for different number of modes.

# %%
colors_K = ['dodgerblue','darkorange','limegreen','crimson','mediumpurple']

# %%
LossPerK = []

for K in range(1,6):
    
    print(f'Running K={K}')
    
    # Initialization
    indices = np.random.choice(X.shape[0], size=K,replace=False)
    mus = np.vstack([X[ii] for ii in indices])
    idx = updateClusters(X,mus)

    L0 = costFct(X,mus,idx)

    for i in range(100):

        # M-step
        mus =  updateCenters(X, idx)

        # E-step
        idx = updateClusters(X,mus)

        L = costFct(X,mus,idx)

        if L == L0:
            break

        L0 = L
    
    LossPerK.append(L)
    print(f'  L={L} ({i} iter)')
    
    drawPlot(X,mus,idx,colors_K[:K],figName=f'{figDir}/K{K}.pdf')
# Out:
# Running K=1
#   L=304.1966060823763 (1 iter)
# Running K=2
#   L=56.852709167535565 (4 iter)
# Running K=3
#   L=48.54867577383591 (5 iter)
# Running K=4
#   L=35.21966271455787 (5 iter)
# Running K=5
#   L=41.993675491134674 (16 iter)

# %%
plt.scatter(np.arange(1,6),LossPerK,200,
            color=colors_K)

plt.xlabel('K (# of clusters)',fontsize=fs)
plt.ylabel('$\mathcal{L}$',fontsize=40,rotation=0,labelpad=20,va='top',y=.9)

ax = plt.gca()
for loc in ['right','top']:
    ax.spines[loc].set_visible(False)

ax.spines['bottom'].set_linewidth(2)
ax.spines['left'].set_linewidth(2)

xlim = [0.5,5.5] #plt.xlim()
_,ymax = plt.ylim()

ax.plot((xlim[1]), (0), ls="", marker=">", 
    ms=16, color="k", clip_on=False)

ax.plot((xlim[0]), (ymax), ls="", marker="^", 
    ms=16, color="k", clip_on=False)

plt.xlim(xlim)
plt.ylim(0,ymax)
plt.savefig(f'{figDir}/loss_varyK.pdf',bbox_inches='tight')

# %% [markdown]
# **Goal:** Come up with a fun activity!!
#
# Plot the number of modes

# %%
# The centers of the Gaussian blobs
c1 = np.array([0,0])
c2 = np.array([2,1])

s1 = .333
s2 = .45

X1 = c1 + s1*np.random.randn(N_tr,2)
X2 = c2 + s2*np.random.randn(N_tr,2)

# %%
Xs = []

for c, s in zip([(0,0),(0,2),(-3,1),(1,-2)],[.333,.45,.6,.4]):
    
    Xi = np.array(c) + s * np.random.randn(N_tr,2)
    Xs.append(Xi)

X = np.vstack(Xs)

# %%
plt.scatter(*X.T,color='grey',alpha=alpha)

plt.xlabel('$x_0$',fontsize=fs)
plt.ylabel('$x_1$',fontsize=fs)

# plt.savefig('figures/Unsup/Kmeans/fourBlobs.pdf',bbox_inches='tight')
# Out:
# Text(0, 0.5, '$x_1$')

# %%
colors_K = ['dodgerblue','darkorange','limegreen','crimson','mediumpurple',
            'hotpink','mediumturquoise' 
           ]

# %%
LossPerK = []

for K in range(1,8):
    
    print(f'Running K={K}')
    
    # Initialization
    indices = np.random.choice(X.shape[0], size=K,replace=False)
    mus = np.vstack([X[ii] for ii in indices])
    idx = updateClusters(X,mus)

    L0 = costFct(X,mus,idx)

    for i in range(100):

        # M-step
        mus =  updateCenters(X, idx)

        # E-step
        idx = updateClusters(X,mus)

        L = costFct(X,mus,idx)

        if L == L0:
            break

        L0 = L
    
    LossPerK.append(L)
    print(f'  L={L} ({i} iter)')
    
    drawPlot(X,mus,idx,colors_K[:K],figName=f'{figDir}/fourBlobs_K{K}.pdf')
# Out:
# Running K=1
#   L=1874.3057120855162 (1 iter)
# Running K=2
#   L=869.4004977920233 (17 iter)
# Running K=3
#   L=328.3766817557761 (14 iter)
# Running K=4
#   L=143.59950765026122 (3 iter)
# Running K=5
#   L=124.61110654479312 (4 iter)
# Running K=6
#   L=113.50239086518313 (6 iter)
# Running K=7
#   L=114.77998935457691 (6 iter)

# %%
plt.scatter(np.arange(1,8),LossPerK,200,
            color=colors_K)

plt.xlabel('K (# of clusters)',fontsize=fs)
plt.ylabel('$\mathcal{L}$',fontsize=40,rotation=0,labelpad=20,va='top',y=.9)

ax = plt.gca()
for loc in ['right','top']:
    ax.spines[loc].set_visible(False)

ax.spines['bottom'].set_linewidth(2)
ax.spines['left'].set_linewidth(2)

xlim = [0.5,7.5] 
_,ymax = plt.ylim()

ax.plot((xlim[1]), (0), ls="", marker=">", 
    ms=16, color="k", clip_on=False)

ax.plot((xlim[0]), (ymax), ls="", marker="^", 
    ms=16, color="k", clip_on=False)

plt.xlim(xlim)
plt.ylim(0,ymax)
plt.savefig(f'{figDir}/fourBlobs_loss.pdf',bbox_inches='tight')
